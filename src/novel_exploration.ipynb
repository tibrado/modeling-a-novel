# %%
# Imports 
import pandas as pd
import numpy as np
import glob

# %%
# Get glossary 
column_names = ['title', 'chapters', 'stars', 'tags', 'followers', 'pages', 'views', 'date']
glossary =  pd.read_csv('../data/index' ,delimiter=';', names = column_names)
# Out:
#                                    title chapters  stars  \
# 0                     Mother of Learning      108   4.83
# 1                      Beware Of Chicken       77   4.82
# 2                           Super Minion       59   4.79
# 3                        The Perfect Run       77   4.79
# 4             A Journey of Black and Red      112   4.73
# ...                                  ...      ...    ...
# 1125                      Fantasy Royale       28   4.38
# 1126                     Dragon Guardian        7   4.55
# 1127                             Scritch       23   4.85
# 1128  Nigmus Online [2nd Draft Complete]       10   4.40
# 1129                The Infinity Project       90   4.22
#
#                                                    tags followers  pages  \
# 0              Original Adventure Fantasy Mystery Magic    12,387  2,930
# 1     Original Adventure Comedy Fantasy Romance Male...    14,836    531
# 2     Original Action Sci-fi Non-Human lead Secret I...    11,233    999
# 3     Original Adventure Comedy Mystery Sci-fi Anti-...     9,051    907
# 4     Original Action Adventure Fantasy Historical F...     6,727  2,086
# ...                                                 ...       ...    ...
# 1125  Original Action Adventure Comedy Fantasy Anti-...       327    492
# 1126  Original Action Fantasy Magic Male Lead Non-Hu...       332     93
# 1127  Original Adventure Comedy Fantasy Female Lead ...        89    132
# 1128  Original Adventure Fantasy LitRPG Magic Multip...       502    111
# 1129  Original Action Adventure Fantasy Horror Grimd...       754  1,307
#
#           views               date
# 0     6,885,030  FEBRUARY 10, 2020
# 1     3,213,761     APRIL 19, 2021
# 2     3,088,026  NOVEMBER 30, 2020
# 3     1,673,316     APRIL 17, 2021
# 4     1,754,156     APRIL 16, 2021
# ...         ...                ...
# 1125     91,042      JUNE 08, 2018
# 1126     36,184   JANUARY 07, 2017
# 1127      8,166  FEBRUARY 08, 2021
# 1128     75,743   JANUARY 22, 2017
# 1129    316,305       MAY 10, 2020
#
# [1130 rows x 8 columns]
